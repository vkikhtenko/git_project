# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Обучение-моделей-с-дисбалансом-классов" data-toc-modified-id="Обучение-моделей-с-дисбалансом-классов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обучение моделей с дисбалансом классов</a></span><ul class="toc-item"><li><span><a href="#Модель-дерева-решений-с-дисбалансом" data-toc-modified-id="Модель-дерева-решений-с-дисбалансом-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Модель дерева решений с дисбалансом</a></span></li><li><span><a href="#Модель-рандомного-леса-с-дисбалансом" data-toc-modified-id="Модель-рандомного-леса-с-дисбалансом-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Модель рандомного леса с дисбалансом</a></span></li></ul></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Downsampling" data-toc-modified-id="Downsampling-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Downsampling</a></span><ul class="toc-item"><li><span><a href="#Модель-дерева-решений" data-toc-modified-id="Модель-дерева-решений-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Модель дерева решений</a></span></li><li><span><a href="#Модель-рандомного-леса" data-toc-modified-id="Модель-рандомного-леса-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Модель рандомного леса</a></span></li></ul></li><li><span><a href="#Upsampling" data-toc-modified-id="Upsampling-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Upsampling</a></span><ul class="toc-item"><li><span><a href="#Модель-дерева-решений" data-toc-modified-id="Модель-дерева-решений-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Модель дерева решений</a></span></li><li><span><a href="#Модель-рандомного-леса" data-toc-modified-id="Модель-рандомного-леса-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Модель рандомного леса</a></span></li></ul></li><li><span><a href="#Выведем-результаты-исследования-моделей-и-выдерем-лучшую-для-тестирования" data-toc-modified-id="Выведем-результаты-исследования-моделей-и-выдерем-лучшую-для-тестирования-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Выведем результаты исследования моделей и выдерем лучшую для тестирования</a></span><ul class="toc-item"><li><span><a href="#Выведем-метрики-F1-для-каждой-модели" data-toc-modified-id="Выведем-метрики-F1-для-каждой-модели-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Выведем метрики F1 для каждой модели</a></span></li><li><span><a href="#Выведем-метрики-AUC-ROC-для-каждой-модели" data-toc-modified-id="Выведем-метрики-AUC-ROC-для-каждой-модели-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Выведем метрики AUC-ROC для каждой модели</a></span></li></ul></li><li><span><a href="#Выводы-по-исследованию-моделей" data-toc-modified-id="Выводы-по-исследованию-моделей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Выводы по исследованию моделей</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span><ul class="toc-item"><li><span><a href="#Проверим-модель-рандомного-леса-с-upsampling" data-toc-modified-id="Проверим-модель-рандомного-леса-с-upsampling-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Проверим модель рандомного леса с upsampling</a></span></li><li><span><a href="#Проверим-модель-рандомного-леса-с-downsampling" data-toc-modified-id="Проверим-модель-рандомного-леса-с-downsampling-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Проверим модель рандомного леса с downsampling</a></span></li><li><span><a href="#Выводы-по-тестированию-модели" data-toc-modified-id="Выводы-по-тестированию-модели-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Выводы по тестированию модели</a></span></li></ul></li><li><span><a href="#Выводы-по-проекту" data-toc-modified-id="Выводы-по-проекту-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы по проекту</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Вам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Постройте модель с предельно большим значением *F1*-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59. Проверьте *F1*-меру на тестовой выборке самостоятельно.
#
# Дополнительно измеряйте *AUC-ROC*, сравнивайте её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Устанавливаем библиотеку phik

# %%
pip install phik
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Импортируем библиотеки

# %%
import time
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.offline as pyo
import phik

from sklearn import tree
from tqdm import tqdm
from phik import report

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.dummy import DummyClassifier
from sklearn.metrics import f1_score
from sklearn.utils import shuffle
from sklearn.metrics import roc_curve 
from sklearn.metrics import roc_auc_score
from phik.report import plot_correlation_matrix
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Скачиваем данные и сохраняем в датафрейм data, в пересенной index_col укажем 0. Покажем первые 5 строк

# %%
data = pd.read_csv('https://code.s3.yandex.net/datasets/Churn.csv', index_col=0)
data.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42     2.0
# 2            15647311      Hill          608     Spain  Female   41     1.0
# 3            15619304      Onio          502    France  Female   42     8.0
# 4            15701354      Boni          699    France  Female   39     1.0
# 5            15737888  Mitchell          850     Spain  Female   43     2.0
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# ...

# %% [markdown]
# Проверим типы данных и пропуски

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           9091 non-null   float64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(3), int64(7), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# Видим пропуски в колонке tenure. Посмотрим, есть ли какая-то зависимость и можно ли эти данные как-либо заполнить. Для этого изучим данные. Начнем с построения гистограм

# %%
data.hist(figsize=(15, 12), bins=20)
plt.show()

# %% [markdown]
# По данным можно заметить следующее:
# 1. Активных и неактивных пользователей примерно поровну
# 2. Зарплаты распределены подозрительно равномерно
# 3. Очень много пользователей с нулевым балансом
# 4. Тех, кто отказался от услуг банка примерно 20%.
# 5. Подавляющее большинсво пользователей используют один или два продукта банка.
# 6. Медианный возраст в районе 40 лет.
# 7. Длительность пользования услугами банка распределена равномерно среди пользователей, но выбиваются те, кто пользуется меньше года или больше 10 лет

# %% [markdown]
# Проверим корреляцию между признаками. Делаем это в том числе для того, чтобы определить зависимость между tenure и другими признаками для заполнения пропусков.

# %%
data_corr = data.corr()
fig, ax = plt.subplots(figsize=(10,7))    
plt.show(sns.heatmap(data_corr, annot=True, fmt=".1f", linewidths=.5))

# %% [markdown]
# Из-за того, что распределение сложно назвать нормальным пока предлагаю убрать данный показатель

# %% [markdown]
# Уточним распределение классов в процентах

# %%
data['Exited'].value_counts() / data['Exited'].count() * 100
# Out:
# 0    79.63
# 1    20.37
# Name: Exited, dtype: float64

# %% [markdown]
# Удалим строки, где отсутсвуют значения

# %%
data = data.dropna().reset_index().set_index('RowNumber')

# %% [markdown]
# Проверим распределение классов в процентах после удаления отсутствующих данных

# %%
data['Exited'].value_counts() / data['Exited'].count() * 100
# Out:
# 0    79.606204
# 1    20.393796
# Name: Exited, dtype: float64

# %% [markdown]
# Разделим выборки на обучающую, валидационную и тестовую. Уберем колонки с фамилией и id из предикторов, так как вряд ли эта информация поможет нам правильно классифицировать пользователей

# %%
features = data.drop(['Exited', 'Surname', 'CustomerId'], axis=1)
target = data['Exited']

# %% [markdown]
# Преобразуем данные в колонках Geography, Gender в численные переменные с помощью метода OHE. Для того, чтобы не попасть в ловушку фиктивных признаков, передадим drop_first=True.

# %% [raw]
# features = pd.get_dummies(features, drop_first=True)
# features.head()

# %% [markdown]
# Передаю в список название колонок для преобразования категориальных значений в численные

# %%
columns_to_transform = ['Geography', 'Gender']
features[columns_to_transform].head()
# Out:
#           Geography  Gender
# RowNumber
# 1            France  Female
# 2             Spain  Female
# 3            France  Female
# 4            France  Female
# 5             Spain  Female

# %%
# создаем объект OHE
ohe = OneHotEncoder(drop='first')
# трансформируем данные 
df_encoded = ohe.fit_transform(features[columns_to_transform])
# создаем новый датафрейм с транформированными данными
df_encoded_df = pd.DataFrame(df_encoded.toarray(), columns=ohe.get_feature_names(columns_to_transform), index=features.index)
# объединяем получившийся датафрейм с изначальным и удаляем лишние колонки
features = pd.concat([features, df_encoded_df], axis=1).drop(columns_to_transform, axis=1)
# отображаем размер данного датафрема
print(features.shape)
# отображаем получившийся датафрейм
features.head()
# Out:
# (9091, 11)
# C:\Users\gogad\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#            CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# RowNumber
# 1                  619   42     2.0       0.00              1          1
# 2                  608   41     1.0   83807.86              1          0
# 3                  502   42     8.0  159660.80              3          1
# 4                  699   39     1.0       0.00              2          0
# 5                  850   43     2.0  125510.82              1          1
#
#            IsActiveMember  EstimatedSalary  Geography_Germany  \
# RowNumber
# 1                       1        101348.88                0.0
# 2                       1        112542.58                0.0
# 3                       0        113931.57                0.0
# ...

# %% [markdown]
# Применим к датафрейму с фичами метод phik_matrix() и округлим значения до сотых

# %%
phik_overview = features.phik_matrix()
phik_overview.round(2)
# Out:
# interval columns not set, guessing: ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Geography_Germany', 'Geography_Spain', 'Gender_Male']
#                    CreditScore   Age  Tenure  Balance  NumOfProducts  \
# CreditScore               1.00  0.00    0.00     0.00           0.04
# Age                       0.00  1.00    0.05     0.03           0.14
# Tenure                    0.00  0.05    1.00     0.06           0.06
# Balance                   0.00  0.03    0.06     1.00           0.37
# NumOfProducts             0.04  0.14    0.06     0.37           1.00
# HasCrCard                 0.01  0.03    0.03     0.05           0.00
# IsActiveMember            0.04  0.19    0.03     0.00           0.06
# EstimatedSalary           0.04  0.06    0.00     0.00           0.03
# Geography_Germany         0.03  0.09    0.02     0.58           0.10
# Geography_Spain           0.04  0.00    0.00     0.20           0.05
# ...

# %%
plot_correlation_matrix(phik_overview.values, 
                        x_labels=phik_overview.columns, 
                        y_labels=phik_overview.index, 
                        vmin=0, vmax=1, color_map="Greens", 
                        title=r"correlation $\phi_K$", 
                        fontsize_factor=1.5, 
                        figsize=(10, 8))
plt.tight_layout()

# %%
significance_overview = features.significance_matrix(interval_cols=features.columns)
plot_correlation_matrix(significance_overview.fillna(0).values, 
                        x_labels=significance_overview.columns, 
                        y_labels=significance_overview.index, 
                        vmin=-5, vmax=5, title="Significance of the coefficients", 
                        usetex=False, fontsize_factor=1.5, figsize=(15, 7))
plt.tight_layout()

# %% [markdown]
# Разделим выборки на обучающую, валидационную и тестовую в пропорциях 60/20/20. Сначала отделим обучающую выборку

# %%
 features_train, valid_test_features, target_train, valid_test_target = train_test_split(features, 
                                                                                         target, 
                                                                                         stratify=target, 
                                                                                         test_size=0.4, 
                                                                                         random_state=12345)

# %% [markdown]
# Проверяем, действительно ли теперь обучающая выборка составляет 60% от всего датафрейма

# %%
print('Размер обучающей выборки:', features_train.shape[0] / features.shape[0])
# Out:
# Размер обучающей выборки: 0.5999340006599934

# %% [markdown]
# Стандартизируем данные. Для этого выделим в отдельный список название фичей с количественными характеристиками

# %%
list_of_featers_to_std = ['CreditScore', 'Age', 'Tenure', 'Balance', 'EstimatedSalary', 'NumOfProducts']

# %%
# передаем StandardScaler в переменную scaler
scaler = StandardScaler()
# обучаем и трансформируем датафрейм
df_standardized = pd.DataFrame(scaler.fit_transform(features_train[list_of_featers_to_std]), columns=list_of_featers_to_std, index=features_train.index)
# merge the standardized columns with the remaining columns in the original dataframe
features_train = pd.concat([features_train[features_train.drop(list_of_featers_to_std, axis=1).columns], df_standardized], axis=1)
# print the standardized dataframe
features_train
# Out:
#            HasCrCard  IsActiveMember  Geography_Germany  Geography_Spain  \
# RowNumber
# 9724               0               0                0.0              0.0
# 1225               1               0                0.0              1.0
# 8378               1               1                0.0              1.0
# 8015               1               1                0.0              1.0
# 2492               1               1                0.0              1.0
# ...              ...             ...                ...              ...
# 3892               1               0                1.0              0.0
# 2676               1               1                1.0              0.0
# 4218               1               1                1.0              0.0
# 5818               0               1                1.0              0.0
# 2672               0               1                0.0              1.0
#
#            Gender_Male  CreditScore       Age    Tenure   Balance  \
# RowNumber
# ...

# %% [markdown]
# Стандартизируем валидационный и тестовый датафреймы

# %%
# трансформируем датафрейм
df_standardized = pd.DataFrame(scaler.transform(valid_test_features[list_of_featers_to_std]), columns=list_of_featers_to_std, index=valid_test_features.index)
# объединяем стандартизованный датафрейм с данными, которые в стандартизации не нуждались
valid_test_features = pd.concat([valid_test_features[valid_test_features.drop(list_of_featers_to_std, axis=1).columns], df_standardized], axis=1)
valid_test_features
# Out:
#            HasCrCard  IsActiveMember  Geography_Germany  Geography_Spain  \
# RowNumber
# 9821               0               0                1.0              0.0
# 763                0               0                1.0              0.0
# 4151               1               0                0.0              0.0
# 1322               0               0                0.0              0.0
# 1859               1               1                0.0              0.0
# ...              ...             ...                ...              ...
# 8443               0               0                0.0              0.0
# 9893               0               1                0.0              1.0
# 129                1               0                0.0              0.0
# 5877               1               0                0.0              0.0
# 9626               1               1                1.0              0.0
#
#            Gender_Male  CreditScore       Age    Tenure   Balance  \
# RowNumber
# ...

# %% [markdown]
# Теперь разделим оставшие 40 % на валидационную и тестовую выборки

# %%
features_valid, features_test, target_valid, target_test = train_test_split(valid_test_features, 
                                                                            valid_test_target, 
                                                                            stratify=valid_test_target, 
                                                                            test_size=0.5, 
                                                                            random_state=12345)

# %% [markdown]
# Проверяем размеры валидационной и тестовой выборок

# %%
print('Размер валидационной выборки:', features_valid.shape[0] / features.shape[0])
print('Размер тестовой выборки:', features_test.shape[0] / features.shape[0])
# Out:
# Размер валидационной выборки: 0.1999780002199978
# Размер тестовой выборки: 0.2000879991200088

# %% [markdown]
# Теперь планирую оставить валидационную и тестовую выборки в таком виде для всех следующих моделей. Изменять буду только обучающую.
# Данные подготовлены. Можно приступать к обучению моделей.

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# ### Обучение моделей с дисбалансом классов

# %% [markdown]
# Обучим модели дерева решений, рандомного леса. Начнем с модели логистической регрессии. Буду добавлять в конце названия disb для обозначания дисбаланса классов в этой модели

# %% [markdown]
# #### Модель дерева решений с дисбалансом

# %%
# Задаем переменную, в которую будет записана лучшая модель дерева решений с дисбалансом
best_model_decision_tree_disb = None
# Задаем пустые списки, в которые будем записывать результаты оценки метрикой F1 на обучающей и валидационной выборках
results_train_decision_tree = []
results_valid_decision_tree = []
# Задаем начальное значение метрики F1
best_result_decision_tree_disb = 0
# Создаем цикл, с помощью которого будем сторить деревья решений с максимальной глубиной от 1 до 20
for depth in range(1, 21):
    # Создаем модель дерева решений с максимальной глубиной согласно циклу
    model_decision_tree = DecisionTreeClassifier(random_state=12345, max_depth=depth)
    # Обучаем модель дерева решений на обучающей выборке    
    model_decision_tree = model_decision_tree.fit(features_train, target_train)
    # Предсказываем классы на обучающей выборке
    predictions_train_decision_tree = model_decision_tree.predict(features_train)
    # Считаем метрику F1 для обучающей выборки
    result_train_decision_tree = f1_score(target_train, predictions_train_decision_tree)
    # Добавляем значение F1 в список    
    results_train_decision_tree.append(result_train_decision_tree)
    # Предсказываем классы на валидационной выборке    
    predictions_valid_decision_tree = model_decision_tree.predict(features_valid)
    # Считаем метрику F1 для валидационной выборки   
    result_valid_decision_tree = f1_score(target_valid, predictions_valid_decision_tree)
    # Добавляем значение F1 в список    
    results_valid_decision_tree.append(result_valid_decision_tree)
    # Проверяем, больше ли метрика F1 на валидационной выборке чем максимальная найденная ранее
    # Если новая метрика больше, то пересохраняем новые значения вместо предыдущих
    if result_valid_decision_tree > best_result_decision_tree_disb:
        best_model_decision_tree_disb = model_decision_tree
        best_result_decision_tree_disb = result_valid_decision_tree
        best_depth_disb = depth
print("F1 лучшей модели дерева решений:", best_result_decision_tree_disb)
print("Глубина лучшей модели дерева решений:", best_depth_disb)
# Out:
# F1 лучшей модели дерева решений: 0.5862646566164155
# Глубина лучшей модели дерева решений: 7

# %% [markdown]
# Создаем датафрейм с полученными метриками F1 на обучающей и валидационной выборках

# %%
df_deс_tree_res = pd.DataFrame({'depth':np.arange(1, 21, 1), 'train': results_train_decision_tree, 'valid': results_valid_decision_tree}).set_index('depth')

# %% [markdown]
# Строим кривые обучения для дерева решений

# %%
df_deс_tree_res.plot(figsize=(15, 5))
plt.show()

# %% [markdown]
# Изобразим первые три уровня лучшего дерева решений

# %%
fig = plt.figure(figsize=(20,10))
_ = tree.plot_tree(best_model_decision_tree_disb, 
                   feature_names=features_valid.columns,  
                   class_names=['0', '1'],
                   filled=True, max_depth=2)

# %%
# предсказываем вероятности классификации объекта в качестве класса 1
probabilities_valid_dt_disb = best_model_decision_tree_disb.predict_proba(features_valid)
probabilities_one_valid_dt_disb = probabilities_valid_dt_disb[:, 1]
# применяем функцию ROC-кривой для определения false positive rate, true positive rate и порогов
fpr_dt_disb, tpr_dt_disb, thresholds_dt_disb = roc_curve(target_valid, probabilities_one_valid_dt_disb)
# создаем график и передаем ему false positive rate и true positive rate
plt.figure()
plt.plot(fpr_dt_disb, tpr_dt_disb)
# строим пунктирную линию для обозначения случайной модели
plt.plot([0, 1], [0, 1], linestyle='--')
# устанавливаем лимиты по x и y
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
# устанавливаем названия осей и графика
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
# выводим график
plt.show()

# %% [markdown]
# Считаем метрику AUC-ROC

# %%
auc_roc_dt_disb = roc_auc_score(target_valid, probabilities_one_valid_dt_disb)
print(auc_roc_dt_disb)
# Out:
# 0.8273908095008354

# %% [markdown]
# #### Модель рандомного леса с дисбалансом

# %% [markdown]
# Создаём датафрейм, в который будем записывать результат обучения модели рандомного леса

# %%
df_random_forest_res = pd.DataFrame({'est':np.arange(1, 101, 1)})

# %% [markdown]
# Обучаем и проверяем метрику F1 рандомного леса

# %%
# Задаем переменную, в которую будет записана лучшая модель рандомного леса с дисбалансом
best_model_random_forest_disb = None
# Задаем начальное значение метрики F1
best_result_random_forest_disb = 0
best_est_disb = 0
# Создаем цикл, с помощью которого будем перебирать максимальную глубину моделей рандомного леса от 1 до 20
# Для контроля времени добавим перед функцию tqdm перед range
#for max_depth_rf in tqdm(range(1, 21)):
for max_depth_rf in tqdm(range(19, 20)):
    # Создаем имя колонок для ранее созданного датафрейма
    column_name_train = 'max_depth_' + str(max_depth_rf) + '_' + 'train'
    column_name_valid = 'max_depth_' + str(max_depth_rf) + '_' + 'valid'
    # Создаем пустые списки для записи в них результатов метрики F1 для валидационной и обучающей выборки
    results_train_random_forest = []
    results_valid_random_forest = []
    # Создаем цикл, с помощью которого будем перебирать количество оценщиков от 1 до 100
    #for est in range(1, 101):
    for est in range(37, 38):
        # Создаем модель рандомного леса с гиперпараметрами согласно циклам
        model_random_forest = RandomForestClassifier(n_estimators=est,
                                                     random_state=12345, 
                                                     max_depth=max_depth_rf)
        # Обучаем модель дерева решений на обучающей выборке 
        model_random_forest = model_random_forest.fit(features_train, 
                                                      target_train)
        # Предсказываем классы на обучающей выборке
        predictions_train_random_forest = model_random_forest.predict(features_train)
        # Считаем метрику F1 для обучающей выборки
        result_train_random_forest = f1_score(target_train, 
                                              predictions_train_random_forest)
        # Добавляем значение F1 в список
        results_train_random_forest.append(result_train_random_forest)
        # Предсказываем классы на валидационной выборке
        predictions_valid_random_forest = model_random_forest.predict(features_valid)
        # Считаем метрику F1 для валидационной выборки
        result_valid_random_forest = f1_score(target_valid, 
                                              predictions_valid_random_forest)
        # Добавляем значение F1 в список
        results_valid_random_forest.append(result_valid_random_forest)
        # Проверяем, больше ли метрика F1 на валидационной выборке чем максимальная найденная ранее
        # Если новая метрика больше, то пересохраняем новые значения вместо предыдущих
        if result_valid_random_forest > best_result_random_forest_disb:
            best_model_random_forest_disb = model_random_forest
            best_result_random_forest_disb = result_valid_random_forest
            best_est_disb = est
            best_depth_rf_disb = max_depth_rf
    # Преобразуем списки в Series
    df_random_forest_res[column_name_train] = pd.Series(results_train_random_forest)
    df_random_forest_res[column_name_valid] = pd.Series(results_valid_random_forest)
print("F1 лучшей модели рандомного леса:", best_result_random_forest_disb)
print("Количество оценщиков лучшей модели рандомного леса:", best_est_disb)
print("Лучшая глубина модели рандомного леса:", best_depth_rf_disb)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.41it/s]
# F1 лучшей модели рандомного леса: 0.6263910969793324
# Количество оценщиков лучшей модели рандомного леса: 37
# Лучшая глубина модели рандомного леса: 19

# %%
# предсказываем вероятности классификации объекта в качестве класса 1
probabilities_valid_rf_disb = best_model_random_forest_disb.predict_proba(features_valid)
probabilities_one_valid_rf_disb = probabilities_valid_rf_disb[:, 1]
# применяем функцию ROC-кривой для определения false positive rate, true positive rate и порогов
fpr_rf_disb, tpr_rf_disb, thresholds_rf_disb = roc_curve(target_valid, probabilities_one_valid_rf_disb)
# создаем график и передаем ему false positive rate и true positive rate
plt.figure()
plt.plot(fpr_rf_disb, tpr_rf_disb)
# строим пунктирную линию для обозначения случайной модели
plt.plot([0, 1], [0, 1], linestyle='--')
# устанавливаем лимиты по x и y
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
# устанавливаем названия осей и графика
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
# выводим график
plt.show()

# %% [markdown]
# Считаем метрику AUC-ROC

# %%
auc_roc_rf_disb = roc_auc_score(target_valid, probabilities_one_valid_rf_disb)
print(auc_roc_rf_disb)
# Out:
# 0.8635358591155229

# %%
print("F1 лучшей модели дерева решений:", best_result_decision_tree_disb)
print("F1 лучшей модели рандомного леса:", best_result_random_forest_disb)
# Out:
# F1 лучшей модели дерева решений: 0.5862646566164155
# F1 лучшей модели рандомного леса: 0.6263910969793324

# %% [markdown]
# В результате проверки различных моделей обучения с использованием исходных данных без исправления дисбаланса оказалось, что самая точная модель - это модель рандомного леса.

# %% [markdown]
# ## Борьба с дисбалансом

# %% [markdown]
# ### Downsampling

# %% [markdown]
# В качестве метода борьбы с дисбалансом сначала попробуем удалить часть данных с помощью техники downsampling

# %% [markdown]
# Задаем функцию для уменьшения выборки

# %%
def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_downsampled = pd.concat(
        [features_zeros.sample(frac=fraction, random_state=12345)] + [features_ones])
    target_downsampled = pd.concat(
        [target_zeros.sample(frac=fraction, random_state=12345)] + [target_ones])
    
    features_downsampled, target_downsampled = shuffle(
        features_downsampled, target_downsampled, random_state=12345)
    
    return features_downsampled, target_downsampled

# %% [markdown]
# Рассчитываем, какую долю данных нужно удалить, чтобы уравнять классы

# %%
fraction = 1 - (target_train.value_counts().max() - target_train.value_counts().min()) / target_train.value_counts().max()
fraction
# Out:
# 0.25610317825886686

# %% [markdown]
# Применяем функцию downsample на обучающей выборке

# %%
features_train_down, target_train_down = downsample(features_train, target_train, fraction)

# %% [markdown]
# Проверяем доли классов

# %%
target_train_down.value_counts(normalize=True)
# Out:
# 1    0.5
# 0    0.5
# Name: Exited, dtype: float64

# %% [markdown]
# Проверяем долю обучающей выборки от изначального датафрейма

# %%
print('Размер обучающей выборки:', features_train_down.shape[0] / features.shape[0])
# Out:
# Размер обучающей выборки: 0.24463755362446377

# %% [markdown]
# Данные подготовлены. Можно приступать к обучению моделей

# %% [markdown]
# Обучим модели дерева решений, рандомного леса. Начнем с модели логистической регрессии. Буду добавлять в конце названия down для обозначания метода downsampling в этой модели

# %% [markdown]
# #### Модель дерева решений

# %% [markdown]
# Создадим модель дерева решений

# %%
# Задаем переменную, в которую будет записана лучшая модель дерева решений с downsampling
best_model_decision_tree_down = None
# Задаем пустые списки, в которые будем записывать результаты оценки метрикой F1 на обучающей и валидационной выборках
results_train_decision_tree_down = []
results_valid_decision_tree_down = []
# Задаем начальное значение метрики F1
best_result_decision_tree_down = 0
# Создаем цикл, с помощью которого будем сторить деревья решений с максимальной глубиной от 1 до 20
for depth in range(1, 21):
    # Создаем модель дерева решений с максимальной глубиной согласно циклу
    model_decision_tree = DecisionTreeClassifier(random_state=12345, 
                                                 max_depth=depth)
    # Обучаем модель дерева решений на обучающей выборке   
    model_decision_tree = model_decision_tree.fit(features_train_down,
                                                  target_train_down)
    # Предсказываем классы на обучающей выборке
    predictions_train_decision_tree = model_decision_tree.predict(features_train_down)
    # Считаем метрику F1 для обучающей выборки    
    result_train_decision_tree = f1_score(target_train_down,
                                          predictions_train_decision_tree)
    # Добавляем значение F1 в список      
    results_train_decision_tree_down.append(result_train_decision_tree)
    # Предсказываем классы на валидационной выборке     
    predictions_valid_decision_tree = model_decision_tree.predict(features_valid)
    # Считаем метрику F1 для валидационной выборки    
    result_valid_decision_tree = f1_score(target_valid,
                                          predictions_valid_decision_tree)
    # Добавляем значение F1 в список     
    results_valid_decision_tree_down.append(result_valid_decision_tree)
    # Проверяем, больше ли метрика F1 на валидационной выборке чем максимальная найденная ранее
    # Если новая метрика больше, то пересохраняем новые значения вместо предыдущих
    if result_valid_decision_tree > best_result_decision_tree_down:
        best_model_decision_tree_down = model_decision_tree
        best_result_decision_tree_down = result_valid_decision_tree
        best_depth_down = depth
print("f1 лучшей модели дерева решений:", best_result_decision_tree_down)
print("Глубина лучшей модели дерева решений:", best_depth_down)
# Out:
# f1 лучшей модели дерева решений: 0.5623721881390594
# Глубина лучшей модели дерева решений: 4

# %% [markdown]
# Создаем датафрейм с результатими проверки F1

# %%
df_deс_tree_res_down = pd.DataFrame({'depth':np.arange(1, 21, 1), 'train': results_train_decision_tree_down, 'valid': results_valid_decision_tree_down}).set_index('depth')

# %% [markdown]
# Выведем кривые обучения на график

# %%
df_deс_tree_res_down.plot(figsize=(15, 5))
plt.show()

# %% [markdown]
# Выведем дерево решений до глубины равной 3

# %%
fig = plt.figure(figsize=(20,10))
_ = tree.plot_tree(best_model_decision_tree_down, 
                   feature_names=features_valid.columns,  
                   class_names=['0', '1'],
                   filled=True, max_depth=2)

# %% [markdown]
# Создаём датафрейм, в который будем записывать результат обучения модели рандомного леса

# %%
df_random_forest_res_down = pd.DataFrame({'est':np.arange(1, 101, 1)})

# %%
# предсказываем вероятности классификации объекта в качестве класса 1
probabilities_valid_dt_down = best_model_decision_tree_down.predict_proba(features_valid)
probabilities_one_valid_dt_down = probabilities_valid_dt_down[:, 1]
# применяем функцию ROC-кривой для определения false positive rate, true positive rate и порогов
fpr_dt_down, tpr_dt_down, thresholds_dt_down = roc_curve(target_valid, probabilities_one_valid_dt_down)
# создаем график и передаем ему false positive rate и true positive rate
plt.figure()
plt.plot(fpr_dt_down, tpr_dt_down)
# строим пунктирную линию для обозначения случайной модели
plt.plot([0, 1], [0, 1], linestyle='--')
# устанавливаем лимиты по x и y
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
# устанавливаем названия осей и графика
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
# выводим график
plt.show()

# %% [markdown]
# Считаем метрику AUC-ROC

# %%
auc_roc_dt_down = roc_auc_score(target_valid, probabilities_one_valid_dt_down)
print(auc_roc_dt_down)
# Out:
# 0.827097424357859

# %% [markdown]
# #### Модель рандомного леса

# %% [markdown]
# Построим модель рандомного леса

# %%
# Задаем переменную, в которую будет записана лучшая модель рандомного леса с downsampling
best_model_random_forest_down = None
# Задаем начальное значение метрики F1
best_result_random_forest_down = 0
best_est_down = 0
# Создаем цикл, с помощью которого будем перебирать максимальную глубину моделей рандомного леса от 1 до 20
# Для контроля времени добавим перед функцию tqdm перед range
for max_depth_rf in tqdm(range(19, 20)):
    # Создаем имя колонок для ранее созданного датафрейма
    column_name_train = 'max_depth_' + str(max_depth_rf) + '_' + 'train'
    column_name_valid = 'max_depth_' + str(max_depth_rf) + '_' + 'valid'
    # Создаем пустые списки для записи в них результатов метрики F1 для валидационной и обучающей выборки
    results_train_random_forest_down = []
    results_valid_random_forest_down = []
    # Создаем цикл, с помощью которого будем перебирать количество оценщиков от 1 до 100
    #for est in range(1, 101):
    for est in range(26, 27):
        # Создаем модель рандомного леса с гиперпараметрами согласно циклам
        model_random_forest = RandomForestClassifier(n_estimators=est, random_state=12345, 
                                                     max_depth=max_depth_rf)
        # Обучаем модель дерева решений на обучающей выборке 
        model_random_forest = model_random_forest.fit(features_train_down, 
                                                      target_train_down)
        # Предсказываем классы на обучающей выборке
        predictions_train_random_forest = model_random_forest.predict(features_train_down)
        # Считаем метрику F1 для обучающей выборки
        result_train_random_forest = f1_score(target_train_down, 
                                              predictions_train_random_forest)
        # Добавляем значение F1 в список
        results_train_random_forest_down.append(result_train_random_forest)
        # Предсказываем классы на валидационной выборке
        predictions_valid_random_forest = model_random_forest.predict(features_valid)
         # Считаем метрику F1 для валидационной выборки
        result_valid_random_forest = f1_score(target_valid, 
                                              predictions_valid_random_forest)
        # Добавляем значение F1 в список
        results_valid_random_forest_down.append(result_valid_random_forest)
        # Проверяем, больше ли метрика F1 на валидационной выборке чем максимальная найденная ранее
        # Если новая метрика больше, то пересохраняем новые значения вместо предыдущих
        if result_valid_random_forest > best_result_random_forest_down:
            best_model_random_forest_down = model_random_forest
            best_result_random_forest_down = result_valid_random_forest
            best_est_down = est
            best_depth_rf_down = max_depth_rf
    # Преобразуем списки в Series
    df_random_forest_res_down[column_name_train] = pd.Series(results_train_random_forest_down)
    df_random_forest_res_down[column_name_valid] = pd.Series(results_valid_random_forest_down)
print("F1 лучшей модели рандомного леса:", best_result_random_forest_down)
print("Количество оценщиков лучшей модели рандомного леса:", best_est_down)
print("Лучшая глубина модели рандомного леса:", best_depth_rf_down)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.29it/s]
# F1 лучшей модели рандомного леса: 0.6222222222222222
# Количество оценщиков лучшей модели рандомного леса: 26
# Лучшая глубина модели рандомного леса: 19

# %%
# предсказываем вероятности классификации объекта в качестве класса 1
probabilities_valid_rf_down = best_model_random_forest_down.predict_proba(features_valid)
probabilities_one_valid_rf_down = probabilities_valid_rf_down[:, 1]
# применяем функцию ROC-кривой для определения false positive rate, true positive rate и порогов
fpr_rf_down, tpr_rf_down, thresholds_rf_down = roc_curve(target_valid, probabilities_one_valid_rf_down)
# создаем график и передаем ему false positive rate и true positive rate
plt.figure()
plt.plot(fpr_rf_down, tpr_rf_down)
# строим пунктирную линию для обозначения случайной модели
plt.plot([0, 1], [0, 1], linestyle='--')
# устанавливаем лимиты по x и y
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
# устанавливаем названия осей и графика
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
# выводим график
plt.show()

# %% [markdown]
# Считаем метрику AUC-ROC

# %%
auc_roc_rf_down = roc_auc_score(target_valid, probabilities_one_valid_rf_down)
print(auc_roc_rf_down)
# Out:
# 0.8646712130497711

# %% [markdown]
# ### Upsampling

# %% [markdown]
# Задаем функцию для увеличения выборки

# %%
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)
    
    return features_upsampled, target_upsampled

# %% [markdown]
# Определяем во сколько раз необходимо увеличить количество строк с классом 1

# %%
fraction = int(round((target_train.value_counts().max()) / target_train.value_counts().min(), 0))
fraction
# Out:
# 4

# %%
features_train_up, target_train_up = upsample(features_train, target_train, fraction)

# %% [markdown]
# Проверяем соотношение классов

# %%
target_train_up.value_counts(normalize=True)
# Out:
# 1    0.50603
# 0    0.49397
# Name: Exited, dtype: float64

# %% [markdown]
# Проверяем долю обучающей выборки от изначального датафрейма

# %%
print('Размер обучающей выборки:', features_train_down.shape[0] / features.shape[0])
# Out:
# Размер обучающей выборки: 0.24463755362446377

# %% [markdown]
# Данные подготовлены. Можно приступать к обучению моделей

# %% [markdown]
# Обучим модели дерева решений, рандомного леса. Начнем с модели логистической регрессии. Буду добавлять в конце названия down для обозначания метода downsampling в этой модели

# %% [markdown]
# #### Модель дерева решений

# %%
# Задаем переменную, в которую будет записана лучшая модель дерева решений с upsampling
best_model_decision_tree_up = None
# Задаем пустые списки, в которые будем записывать результаты оценки метрикой F1 на обучающей и валидационной выборках
results_train_decision_tree_up = []
results_valid_decision_tree_up = []
# Задаем начальное значение метрики F1
best_result_decision_tree_up = 0
# Создаем цикл, с помощью которого будем сторить деревья решений с максимальной глубиной от 1 до 20
for depth in range(1, 21):
    # Создаем модель дерева решений с максимальной глубиной согласно циклу
    model_decision_tree = DecisionTreeClassifier(random_state=12345, 
                                                 max_depth=depth)
    # Обучаем модель дерева решений на обучающей выборке   
    model_decision_tree = model_decision_tree.fit(features_train_up,
                                                  target_train_up)
    # Предсказываем классы на обучающей выборке
    predictions_train_decision_tree = model_decision_tree.predict(features_train_up)
    # Считаем метрику F1 для обучающей выборки    
    result_train_decision_tree = f1_score(target_train_up,
                                          predictions_train_decision_tree)
    # Добавляем значение F1 в список      
    results_train_decision_tree_up.append(result_train_decision_tree)
    # Предсказываем классы на валидационной выборке     
    predictions_valid_decision_tree = model_decision_tree.predict(features_valid)
    # Считаем метрику F1 для валидационной выборки    
    result_valid_decision_tree = f1_score(target_valid,
                                          predictions_valid_decision_tree)
    # Добавляем значение F1 в список     
    results_valid_decision_tree_up.append(result_valid_decision_tree)
    # Проверяем, больше ли метрика F1 на валидационной выборке чем максимальная найденная ранее
    # Если новая метрика больше, то пересохраняем новые значения вместо предыдущих
    if result_valid_decision_tree > best_result_decision_tree_up:
        best_model_decision_tree_up = model_decision_tree
        best_result_decision_tree_up = result_valid_decision_tree
        best_depth_up = depth
print("f1 лучшей модели дерева решений:", best_result_decision_tree_up)
print("Глубина лучшей модели дерева решений:", best_depth_up)
# Out:
# f1 лучшей модели дерева решений: 0.583084577114428
# Глубина лучшей модели дерева решений: 6

# %% [markdown]
# Создаем датафрейм с результатими проверки F1

# %%
df_deс_tree_res_up = pd.DataFrame({'depth':np.arange(1, 21, 1), 'train': results_train_decision_tree_up, 'valid': results_valid_decision_tree_up}).set_index('depth')

# %% [markdown]
# Выведем кривые обучения на график

# %%
df_deс_tree_res_up.plot(figsize=(15, 5))
plt.show()

# %% [markdown]
# Выведем дерево решений до глубины равной 3

# %%
fig = plt.figure(figsize=(20,10))
_ = tree.plot_tree(best_model_decision_tree_up, 
                   feature_names=features_valid.columns,  
                   class_names=['0', '1'],
                   filled=True, max_depth=2)

# %% [markdown]
# Создаём датафрейм, в который будем записывать результат обучения модели рандомного леса

# %%
df_random_forest_res_up = pd.DataFrame({'est':np.arange(1, 101, 1)})

# %%
# предсказываем вероятности классификации объекта в качестве класса 1
probabilities_valid_dt_up = best_model_decision_tree_up.predict_proba(features_valid)
probabilities_one_valid_dt_up = probabilities_valid_dt_up[:, 1]
# применяем функцию ROC-кривой для определения false positive rate, true positive rate и порогов
fpr_dt_up, tpr_dt_up, thresholds_dt_up = roc_curve(target_valid, probabilities_one_valid_dt_up)
# создаем график и передаем ему false positive rate и true positive rate
plt.figure()
plt.plot(fpr_dt_up, tpr_dt_up)
# строим пунктирную линию для обозначения случайной модели
plt.plot([0, 1], [0, 1], linestyle='--')
# устанавливаем лимиты по x и y
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
# устанавливаем названия осей и графика
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
# выводим график
plt.show()

# %% [markdown]
# Считаем метрику AUC-ROC

# %%
auc_roc_dt_up = roc_auc_score(target_valid, probabilities_one_valid_dt_up)
print(auc_roc_dt_up)
# Out:
# 0.8353671598641673

# %% [markdown]
# #### Модель рандомного леса

# %%
# Задаем переменную, в которую будет записана лучшая модель рандомного леса с downsampling
best_model_random_forest_up = None
# Задаем начальное значение метрики F1
best_result_random_forest_up = 0
best_est_up = 0
# Создаем цикл, с помощью которого будем перебирать максимальную глубину моделей рандомного леса от 1 до 20
# Для контроля времени добавим перед функцию tqdm перед range
#for max_depth_rf in tqdm(range(1, 21)):
for max_depth_rf in tqdm(range(11, 12)):
    # Создаем имя колонок для ранее созданного датафрейма
    column_name_train = 'max_depth_' + str(max_depth_rf) + '_' + 'train'
    column_name_valid = 'max_depth_' + str(max_depth_rf) + '_' + 'valid'
    # Создаем пустые списки для записи в них результатов метрики F1 для валидационной и обучающей выборки
    results_train_random_forest_up = []
    results_valid_random_forest_up = []
    # Создаем цикл, с помощью которого будем перебирать количество оценщиков от 1 до 100
    #for est in range(1, 101):
    for est in range(80, 81):
        # Создаем модель рандомного леса с гиперпараметрами согласно циклам
        model_random_forest = RandomForestClassifier(n_estimators=est, random_state=12345, 
                                                     max_depth=max_depth_rf)
        # Обучаем модель дерева решений на обучающей выборке 
        model_random_forest = model_random_forest.fit(features_train_up, 
                                                      target_train_up)
        # Предсказываем классы на обучающей выборке
        predictions_train_random_forest = model_random_forest.predict(features_train_up)
        # Считаем метрику F1 для обучающей выборки
        result_train_random_forest = f1_score(target_train_up, 
                                              predictions_train_random_forest)
        # Добавляем значение F1 в список
        results_train_random_forest_up.append(result_train_random_forest)
        # Предсказываем классы на валидационной выборке
        predictions_valid_random_forest = model_random_forest.predict(features_valid)
         # Считаем метрику F1 для валидационной выборки
        result_valid_random_forest = f1_score(target_valid, 
                                              predictions_valid_random_forest)
        # Добавляем значение F1 в список
        results_valid_random_forest_up.append(result_valid_random_forest)
        # Проверяем, больше ли метрика F1 на валидационной выборке чем максимальная найденная ранее
        # Если новая метрика больше, то пересохраняем новые значения вместо предыдущих
        if result_valid_random_forest > best_result_random_forest_up:
            best_model_random_forest_up = model_random_forest
            best_result_random_forest_up = result_valid_random_forest
            best_est_up = est
            best_depth_rf_up = max_depth_rf
    # Преобразуем списки в Series
    df_random_forest_res_up[column_name_train] = pd.Series(results_train_random_forest_up)
    df_random_forest_res_up[column_name_valid] = pd.Series(results_valid_random_forest_up)
print("F1 лучшей модели рандомного леса:", best_result_random_forest_up)
print("Количество оценщиков лучшей модели рандомного леса:", best_est_up)
print("Лучшая глубина модели рандомного леса:", best_depth_rf_up)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.04s/it]
# F1 лучшей модели рандомного леса: 0.6415094339622642
# Количество оценщиков лучшей модели рандомного леса: 80
# Лучшая глубина модели рандомного леса: 11

# %%
# предсказываем вероятности классификации объекта в качестве класса 1
probabilities_valid_rf_up = best_model_random_forest_up.predict_proba(features_valid)
probabilities_one_valid_rf_up = probabilities_valid_rf_up[:, 1]
# применяем функцию ROC-кривой для определения false positive rate, true positive rate и порогов
fpr_rf_up, tpr_rf_up, thresholds_rf_up = roc_curve(target_valid, probabilities_one_valid_rf_up)
# создаем график и передаем ему false positive rate и true positive rate
plt.figure()
plt.plot(fpr_rf_up, tpr_rf_up)
# строим пунктирную линию для обозначения случайной модели
plt.plot([0, 1], [0, 1], linestyle='--')
# устанавливаем лимиты по x и y
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
# устанавливаем названия осей и графика
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
# выводим график
plt.show()

# %% [markdown]
# Считаем метрику AUC-ROC

# %%
auc_roc_rf_up = roc_auc_score(target_valid, probabilities_one_valid_rf_up)
print(auc_roc_rf_up)
# Out:
# 0.8706441620082074

# %% [markdown]
# ### Выведем результаты исследования моделей и выдерем лучшую для тестирования

# %% [markdown]
# #### Выведем метрики F1 для каждой модели

# %%
print("F1 лучшей модели дерева решений с дисбалансом:", best_result_decision_tree_disb)
print("F1 лучшей модели рандомного леса с дисбалансом:", best_result_random_forest_disb)
# Out:
# F1 лучшей модели дерева решений с дисбалансом: 0.5862646566164155
# F1 лучшей модели рандомного леса с дисбалансом: 0.6263910969793324

# %%
print("F1 лучшей модели дерева решений с downsampling:", best_result_decision_tree_down)
print("F1 лучшей модели рандомного леса с downsampling:", best_result_random_forest_down)
# Out:
# F1 лучшей модели дерева решений с downsampling: 0.5623721881390594
# F1 лучшей модели рандомного леса с downsampling: 0.6222222222222222

# %%
print("F1 лучшей модели дерева решений с upsampling:", best_result_decision_tree_up)
print("F1 лучшей модели рандомного леса с upsampling:", best_result_random_forest_up)
# Out:
# F1 лучшей модели дерева решений с upsampling: 0.583084577114428
# F1 лучшей модели рандомного леса с upsampling: 0.6415094339622642

# %% [markdown]
# #### Выведем метрики AUC-ROC для каждой модели

# %%
print("AUC-ROC лучшей модели дерева решений с дисбалансом:", auc_roc_dt_disb)
print("AUC-ROC лучшей модели рандомного леса с дисбалансом:", auc_roc_rf_disb)
# Out:
# AUC-ROC лучшей модели дерева решений с дисбалансом: 0.8273908095008354
# AUC-ROC лучшей модели рандомного леса с дисбалансом: 0.8635358591155229

# %%
print("AUC-ROC лучшей модели дерева решений с downsampling:", auc_roc_dt_down)
print("AUC-ROC лучшей модели рандомного леса с downsampling:", auc_roc_rf_down)
# Out:
# AUC-ROC лучшей модели дерева решений с downsampling: 0.827097424357859
# AUC-ROC лучшей модели рандомного леса с downsampling: 0.8646712130497711

# %%
print("AUC-ROC лучшей модели дерева решений с upsampling:", auc_roc_dt_up)
print("AUC-ROC лучшей модели рандомного леса с upsampling:", auc_roc_rf_up)
# Out:
# AUC-ROC лучшей модели дерева решений с upsampling: 0.8353671598641673
# AUC-ROC лучшей модели рандомного леса с upsampling: 0.8706441620082074

# %% [markdown]
# ### Выводы по исследованию моделей

# %% [markdown]
# После проверки 6ти моделей с дисбалансом, с применением метода downsampling и upsampling было выявлено, что лучшая модель во всех случаях - это модель рандомного леса. По критериям F1 и AUC-ROC подходят модели рандомного леса с upsampling и downsampling. Что в этоге работает лучше, проверим на тестовой выборке

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# ### Проверим модель рандомного леса с upsampling

# %% [markdown]
# Проверяем метрику F1

# %%
# Предсказываем значения на тестовой выборке
predictions_test_random_forest = best_model_random_forest_up.predict(features_test)
# Считаем метрику F1 для валидационной выборки
result_test_random_forest = f1_score(target_test, 
                                     predictions_test_random_forest)
print("F1 лучшей модели рандомного леса upsampling:", best_result_random_forest_up)
# Out:
# F1 лучшей модели рандомного леса upsampling: 0.6415094339622642

# %% [markdown]
# Проверяем метрику AUC-ROC

# %%
# предсказываем вероятности классификации объекта в качестве класса 1
probabilities_test_rf_up = best_model_random_forest_up.predict_proba(features_test)
probabilities_one_test_rf_up = probabilities_test_rf_up[:, 1]
# применяем функцию ROC-кривой для определения false positive rate, true positive rate и порогов
fpr_rf_up, tpr_rf_up, thresholds_rf_up = roc_curve(target_test, probabilities_one_test_rf_up)
# создаем график и передаем ему false positive rate и true positive rate
plt.figure()
plt.plot(fpr_rf_up, tpr_rf_up)
# строим пунктирную линию для обозначения случайной модели
plt.plot([0, 1], [0, 1], linestyle='--')
# устанавливаем лимиты по x и y
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
# устанавливаем названия осей и графика
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
# выводим график
plt.show()

# %% [markdown]
# Считаем метрику AUC-ROC

# %%
auc_roc_rf_up_test = roc_auc_score(target_test, probabilities_one_test_rf_up)
print('AUC-ROC на тестовой выборке RF upsampling:', auc_roc_rf_up_test)
# Out:
# AUC-ROC на тестовой выборке RF upsampling: 0.8488537028488035

# %% [markdown]
# ### Проверим модель рандомного леса с downsampling

# %% [markdown]
# Проверяем метрику F1

# %%
# Предсказываем значения на тестовой выборке
predictions_test_random_forest = best_model_random_forest_down.predict(features_test)
# Считаем метрику F1 для валидационной выборки
result_test_random_forest = f1_score(target_test, 
                                     predictions_test_random_forest)
print("F1 лучшей модели рандомного леса downsampling:", best_result_random_forest_down)
# Out:
# F1 лучшей модели рандомного леса downsampling: 0.6222222222222222

# %% [markdown]
# Проверяем метрику AUC-ROC

# %%
# предсказываем вероятности классификации объекта в качестве класса 1
probabilities_test_rf_down = best_model_random_forest_down.predict_proba(features_test)
probabilities_one_test_rf_down = probabilities_test_rf_down[:, 1]
# применяем функцию ROC-кривой для определения false positive rate, true positive rate и порогов
fpr_rf_down, tpr_rf_down, thresholds_rf_down = roc_curve(target_test, probabilities_one_test_rf_down)
# создаем график и передаем ему false positive rate и true positive rate
plt.figure()
plt.plot(fpr_rf_down, tpr_rf_down)
# строим пунктирную линию для обозначения случайной модели
plt.plot([0, 1], [0, 1], linestyle='--')
# устанавливаем лимиты по x и y
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
# устанавливаем названия осей и графика
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
# выводим график
plt.show()

# %% [markdown]
# Считаем метрику AUC-ROC

# %%
auc_roc_rf_down_test = roc_auc_score(target_test, probabilities_one_test_rf_down)
print('AUC-ROC на тестовой выборке RF upsampling:', auc_roc_rf_down_test)
# Out:
# AUC-ROC на тестовой выборке RF upsampling: 0.8311268633378506

# %% [markdown]
# ### Выводы по тестированию модели

# %% [markdown]
# В итоге проверка показала, что наилучшей моделью является модель рандомного леса с использованием метода upsampling со следующими характеристиками:
#
# F1 = 0.648,
#
# AUC-ROC = 0.849

# %% [markdown]
# ## Выводы по проекту

# %% [markdown]
# 1. Начал проект с загрузки данных. Сохранил данные в переменную data.
#
#
# 2. Далее перешел к анализу данных.
#
#     2.1. С помощью метода info() определил, что в столбце tenure отсутствует часть данных. Решил проверить, есть ли какая-нибудь связь с другими данными, чтобы заполнить их. Для этого построил гистограммы по каждому признаку. Посмотрел корреляции Пирсона и использовал phik_matrix для определения зависимостей. В итоге зависимости этой переменной с другими данными не обнаружил и решил их удалить. Но вопрос при этом остался открытым: что с ними можно было сделать?
#
#     2.2. В ходе анализа заметил следующие особенности данных:
#
#         2.2.1. Активных и неактивных пользователей примерно поровну
#
#         2.2.2. Зарплаты распределены подозрительно равномерно
#
#         2.2.3. Очень много пользователей с нулевым балансом
#
#         2.2.4. Тех, кто отказался от услуг банка примерно 20%.
#
#         2.2.5. Подавляющее большинсво пользователей используют один или два продукта банка.
#
#         2.2.6. Медианный возраст в районе 40 лет.
#
#         2.2.7. Длительность пользования услугами банка распределена равномерно среди пользователей, но выбиваются те, кто пользуется меньше года или больше 10 лет
#
#     2.3. Проверил дисбаланс классов. Соотношение оставшихся клиентов к покившим банк составляет примерно 80 на 20 %.
#
#     2.4. Разделил выборки на обучающую, валидационную и тестовую в пропорциях 60/20/20. Убрал колонки с фамилией и id из предикторов, так как вряд ли эта информация поможет нам правильно классифицировать пользователей
#
#     2.5. Преобразовал данные в колонках Geography, Gender в численные переменные с помощью метода OHE. Для того, чтобы не попасть в ловушку фиктивных признаков, передал drop_first=True.
#
#     2.6. Стандартизировал данные во всех трех выборках
#
#
# 3. Перешел к исследованию задачи
#
#     3.1. Обучил модели дерева решений и рандомного леса. Проверил на каждой из них метрики F1, AUC-ROC и построил ROC-кривую. В итоге оказалось, что на данных с дисбалансом лучше всего работает модель рандомного леса. F1 = 0.626, AUC-ROC = 0.863.
#
#     3.2. Для устанения дисбаланса воспользовался техникой downsampling. Обучил те же модели. Проверил на каждой из них метрики F1, AUC-ROC и построил ROC-кривую. В итоге также оказалось, что лучше всего работает модель рандомного леса. F1 = 0.622, AUC-ROC = 0.864.
#
#     3.3. Для сравнения воспользовался техникой upsampling. Обучил те же модели. Проверил на каждой из них метрики F1, AUC-ROC и построил ROC-кривую. В итоге также оказалось, что лучше всего работает модель рандомного леса. F1 = 0.649, AUC-ROC = 0.870.
#
#
# 4. Тестирование моделей рандомного леса с upsampling и downsampling.
#
#     4.1. На тестовой выборке модель рандомного леса, обученного на данных с применением техники upsampling показала следующие метрики: F1 = 0.648, AUC-ROC = 0.849
#
#     4.2. На тестовой выборке модель рандомного леса, обученного на данных с применением техники downsampling показала следующие метрики: F1 = 0.622, AUC-ROC = 0.831
#
#     4.3. Итого выбираем модель рандомного леса с upsampling из-за более высоких метрик.
#
#
# 5. Теперь данную модель можно использовать для выявления клиентов, у которых высок риск отказа от услуг банка. Теперь эту информацию мы сможем предпринять меры, препятствующие их уходу.

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнен шаг 1: данные подготовлены
# - [x]  Выполнен шаг 2: задача исследована
#     - [x]  Исследован баланс классов
#     - [x]  Изучены модели без учёта дисбаланса
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 3: учтён дисбаланс
#     - [x]  Применено несколько способов борьбы с дисбалансом
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 4: проведено тестирование
# - [x]  Удалось достичь *F1*-меры не менее 0.59
# - [x]  Исследована метрика *AUC-ROC*
